# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\TMP\\STA2104finaldata.csv')
df
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0       2011      1           1          6   1400.0   1500.0            AA
# 1       2011      1           2          7   1401.0   1501.0            AA
# 2       2011      1           3          1   1352.0   1502.0            AA
# 3       2011      1           4          2   1403.0   1513.0            AA
# 4       2011      1           5          3   1405.0   1507.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 227491  2011     12           6          2   1818.0   2111.0            WN
# 227492  2011     12           6          2   2047.0   2334.0            WN
# 227493  2011     12           6          2    912.0   1031.0            WN
# 227494  2011     12           6          2    656.0    812.0            WN
# 227495  2011     12           6          2   1600.0   1713.0            WN
#
# ...

# %%
df.groupby('FlightNum').aggregate({'ArrDelay':np.mean, 'DepDelay': np.mean})
# Out:
#             ArrDelay   DepDelay
# FlightNum
# 1           6.745424  11.374793
# 2          -1.640167  -0.441667
# 3           2.271318   5.158301
# 4          -2.827309   3.162698
# 5           6.200000   7.603738
# ...              ...        ...
# 7033      -23.000000  -5.000000
# 7037       19.000000  18.487805
# 7231       -9.000000  -8.000000
# 7240       -6.750000   5.500000
# 7290      -22.000000  -7.500000
#
# [3740 rows x 2 columns]

# %%
df.groupby('TailNum').aggregate({'ArrDelay':np.mean, 'DepDelay':np.mean})
# Out:
#           ArrDelay   DepDelay
# TailNum
# N0EGMQ    1.918919  12.270270
# N10156    8.199357   7.628205
# N10575   18.148936  16.531915
# N11106   10.101639   9.990228
# N11107    8.052786   7.680352
# ...            ...        ...
# N997DL   -2.545455   1.363636
# N998AT   -1.210526   2.473684
# N998DL   -7.333333  -0.166667
# N999DN   -7.285714  -3.142857
# N9EAMQ   12.545455  13.750000
#
# [3319 rows x 2 columns]

# %%
df.loc[df.DayOfWeek == 1, ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 2       2011      1           3          1   1352.0   1502.0            AA
# 9       2011      1          10          1   1443.0   1553.0            AA
# 16      2011      1          17          1   1530.0   1634.0            AA
# 23      2011      1          24          1   1356.0   1513.0            AA
# 30      2011      1          31          1   1441.0   1553.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 227360  2011     12           5          1   1820.0   2111.0            WN
# 227361  2011     12           5          1   2043.0   2329.0            WN
# 227362  2011     12           5          1    923.0   1041.0            WN
# 227363  2011     12           5          1    703.0    818.0            WN
# 227364  2011     12           5          1   1627.0   1741.0            WN
#
# ...

# %%
df.loc[df.DayOfWeek == 7, ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 1       2011      1           2          7   1401.0   1501.0            AA
# 8       2011      1           9          7   1443.0   1554.0            AA
# 15      2011      1          16          7   1359.0   1509.0            AA
# 22      2011      1          23          7   1356.0   1501.0            AA
# 29      2011      1          30          7   1359.0   1456.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 227229  2011     12           4          7   1904.0   2149.0            WN
# 227230  2011     12           4          7   1323.0   1629.0            WN
# 227231  2011     12           4          7   2040.0   2322.0            WN
# 227232  2011     12           4          7   1601.0   1712.0            WN
# 227233  2011     12           4          7    929.0   1049.0            WN
#
# ...

# %%
df.loc[df.DayOfWeek == 2, ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 3       2011      1           4          2   1403.0   1513.0            AA
# 10      2011      1          11          2   1429.0   1539.0            AA
# 17      2011      1          18          2   1408.0   1508.0            AA
# 24      2011      1          25          2   1352.0   1452.0            AA
# 34      2011      1           4          2    714.0    821.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 227491  2011     12           6          2   1818.0   2111.0            WN
# 227492  2011     12           6          2   2047.0   2334.0            WN
# 227493  2011     12           6          2    912.0   1031.0            WN
# 227494  2011     12           6          2    656.0    812.0            WN
# 227495  2011     12           6          2   1600.0   1713.0            WN
#
# ...

# %%
df.loc[df.DayOfWeek == 3, ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 4       2011      1           5          3   1405.0   1507.0            AA
# 11      2011      1          12          3   1419.0   1515.0            AA
# 18      2011      1          19          3   1356.0   1503.0            AA
# 25      2011      1          26          3   1353.0   1455.0            AA
# 35      2011      1           5          3    718.0    822.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 226716  2011     12          28          3    623.0   1020.0            US
# 226717  2011     12          28          3   1305.0   1703.0            US
# 226718  2011     12          28          3   1748.0   2155.0            US
# 226719  2011     12          28          3    659.0   1014.0            US
# 226720  2011     12          28          3   1538.0   1859.0            US
#
# ...

# %%
df.loc[df.DayOfWeek == 4, ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 5       2011      1           6          4   1359.0   1503.0            AA
# 12      2011      1          13          4   1358.0   1501.0            AA
# 19      2011      1          20          4   1507.0   1622.0            AA
# 26      2011      1          27          4   1356.0   1458.0            AA
# 36      2011      1           6          4    719.0    821.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 226890  2011     12           1          4   1836.0   2122.0            WN
# 226891  2011     12           1          4   2054.0   2338.0            WN
# 226892  2011     12           1          4    913.0   1032.0            WN
# 226893  2011     12           1          4    657.0    813.0            WN
# 226894  2011     12           1          4   1603.0   1718.0            WN
#
# ...

# %%
sat = df.loc[df.DayOfWeek == 6, ]
sun = df.loc[df.DayOfWeek == 7, ]
pd.concat([sat, sun])
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0       2011      1           1          6   1400.0   1500.0            AA
# 7       2011      1           8          6   1355.0   1454.0            AA
# 14      2011      1          15          6   1359.0   1459.0            AA
# 21      2011      1          22          6   1355.0   1456.0            AA
# 28      2011      1          29          6   1355.0   1455.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 227229  2011     12           4          7   1904.0   2149.0            WN
# 227230  2011     12           4          7   1323.0   1629.0            WN
# 227231  2011     12           4          7   2040.0   2322.0            WN
# 227232  2011     12           4          7   1601.0   1712.0            WN
# 227233  2011     12           4          7    929.0   1049.0            WN
#
# ...

# %%
df.loc[df.UniqueCarrier == 'AA',:]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0       2011      1           1          6   1400.0   1500.0            AA
# 1       2011      1           2          7   1401.0   1501.0            AA
# 2       2011      1           3          1   1352.0   1502.0            AA
# 3       2011      1           4          2   1403.0   1513.0            AA
# 4       2011      1           5          3   1405.0   1507.0            AA
# ...      ...    ...         ...        ...      ...      ...           ...
# 208661  2011     12          27          2   1021.0   1333.0            AA
# 208662  2011     12          28          3   1015.0   1329.0            AA
# 208663  2011     12          29          4   1023.0   1335.0            AA
# 208664  2011     12          30          5   1024.0   1334.0            AA
# 208665  2011     12          31          6   1024.0   1343.0            AA
#
# ...

# %%
df.loc[df.CancellationCode == 'A', ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 194     2011      1          24          1      NaN      NaN            AA
# 335     2011      1          19          3      NaN      NaN            B6
# 803     2011      1          29          6      NaN      NaN            CO
# 2537    2011      1          20          4      NaN      NaN            CO
# 2894    2011      1          18          2      NaN      NaN            CO
# ...      ...    ...         ...        ...      ...      ...           ...
# 226999  2011     12           2          5      NaN      NaN            WN
# 227047  2011     12           3          6      NaN      NaN            WN
# 227153  2011     12           4          7      NaN      NaN            WN
# 227271  2011     12           5          1      NaN      NaN            WN
# 227394  2011     12           6          2      NaN      NaN            WN
#
# ...

# %%
df.loc[df.CancellationCode == 'B', ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 210     2011      1           9          7      NaN      NaN            AA
# 323     2011      1          11          2      NaN      NaN            B6
# 347     2011      1          27          4      NaN      NaN            B6
# 415     2011      1          31          1      NaN      NaN            CO
# 424     2011      1          31          1      NaN      NaN            CO
# ...      ...    ...         ...        ...      ...      ...           ...
# 224520  2011     12          30          5      NaN      NaN            XE
# 224817  2011     12          22          4   1633.0      NaN            OO
# 224964  2011     12          29          4      NaN      NaN            OO
# 225366  2011     12          31          6      NaN      NaN            OO
# 225694  2011     12           4          7      NaN      NaN            OO
#
# ...

# %%
df.loc[df.CancellationCode == 'D', ]
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 109821  2011      6           3          5      NaN      NaN            OO
#
#         FlightNum TailNum  ActualElapsedTime  ...  ArrDelay  DepDelay  Origin  \
# 109821       1136  N784SK                NaN  ...       NaN       NaN     IAH
#
#        Dest Distance  TaxiIn  TaxiOut  Cancelled  CancellationCode Diverted
# 109821  MCI      643     NaN      NaN          1                 D        0
#
# [1 rows x 21 columns]

# %%
diverted_num = df["Diverted"].cumsum()
diverted_num
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 227491    649
# 227492    649
# 227493    649
# 227494    649
# 227495    649
# Name: Diverted, Length: 227496, dtype: int64

# %%
cancel_num = df["Cancelled"].cumsum()
cancel_num
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#           ...
# 227491    2973
# 227492    2973
# 227493    2973
# 227494    2973
# 227495    2973
# Name: Cancelled, Length: 227496, dtype: int64
